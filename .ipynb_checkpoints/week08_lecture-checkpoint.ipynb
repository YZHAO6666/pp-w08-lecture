# %% [markdown]
# # Edinburgh cycle hire data
#
# Until a few weeks ago (unfortunately!), Edinburgh had a bike hire scheme, where you could rent a bike from one station to another. The company which ran the scheme published anonymised data every month, containing all information about the bike trips people have made that month.
#
# All available data files (since the scheme started in September 2018) are available [here](https://edinburghcyclehire.com/open-data/historical), as well as a description of the data. It is published under the [Open Government License (OGL)](https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/).
#
# The data file for July 2021 is in this folder (`07.csv`).
#
# ---
#
# Some questions we could investigate:
#
# - What is the average journey time and distance of bike trips on weekdays? What about weekends?
# - How many stations appear in the dataset? Which were the most common starting stations?
# - What was the most common time(s) of day for journeys to be undertaken?
#
# ---
#
# Useful documentation:
#
# - [`pandas.to_datetime()`](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html?highlight=to_datetime#pandas.to_datetime)
# - [The `.dt` accessor](https://pandas.pydata.org/docs/user_guide/basics.html#dt-accessor)
# - [Time and date components](https://pandas.pydata.org/docs/user_guide/timeseries.html#time-date-components)
# - Relational plots: [`sns.relplot()`](https://seaborn.pydata.org/generated/seaborn.relplot.html)
# - Categorical plots: [`sns.catplot()`](https://seaborn.pydata.org/generated/seaborn.catplot.html)
# - Distribution plots: [`sns.displot()`](https://seaborn.pydata.org/generated/seaborn.displot.html)

# %%
import pandas as pd

trips = pd.read_csv('07.csv')
trips.head(5)
# Out:
#                          started_at                          ended_at  \
# 0  2021-07-01 00:06:40.633000+00:00  2021-07-01 00:31:13.327000+00:00
# 1  2021-07-01 00:09:05.813000+00:00  2021-07-01 00:18:37.419000+00:00
# 2  2021-07-01 00:29:16.151000+00:00  2021-07-01 01:00:58.224000+00:00
# 3  2021-07-01 00:36:00.185000+00:00  2021-07-01 01:04:08.705000+00:00
# 4  2021-07-01 00:37:13.872000+00:00  2021-07-01 01:01:59.244000+00:00
#
#    duration  start_station_id start_station_name  \
# 0      1472              1102  Haymarket Station
# 1       571              1052      Surgeons Hall
# 2      1902              1039       Lothian Road
# 3      1688              1091      Holyrood Road
# 4      1485              1721          Tollcross
#
#                 start_station_description  start_station_latitude  \
# 0                       Haymarket Station               55.945569
# 1            East side of Nicolson Street               55.946643
# 2                  Outside the Usher Hall               55.947409
# 3               Opposite St Leonards Land               55.949560
# 4  Outside Piccolinos off Lauriston Place               55.944248
#
#    start_station_longitude  end_station_id end_station_name  \
# 0                -3.218185            1729    McDonald Road
# 1                -3.185475            1749      Dean Street
# 2                -3.205765            1824      Duke Street
# 3                -3.180413            1769  Brunswick Place
# 4                -3.203105            1824      Duke Street
#
#               end_station_description  end_station_latitude  \
# 0                Next to Fire Station             55.964031
# 1            Corner of Dean Park Mews             55.957278
# 2           Junction with Easter Road             55.969012
# 3  Corner of Elm Row/Brunswick Street             55.960852
# 4           Junction with Easter Road             55.969012
#
#    end_station_longitude
# 0              -3.185175
# 1              -3.214285
# 2              -3.167395
# 3              -3.180986
# 4              -3.167395

# %%
trips['duration'].mean() / 60
# Out:
# 32.53021454460423

# %%
trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11404 entries, 0 to 11403
# Data columns (total 13 columns):
# started_at                   11404 non-null object
# ended_at                     11404 non-null object
# duration                     11404 non-null int64
# start_station_id             11404 non-null int64
# start_station_name           11404 non-null object
# start_station_description    11237 non-null object
# start_station_latitude       11404 non-null float64
# start_station_longitude      11404 non-null float64
# end_station_id               11404 non-null int64
# end_station_name             11404 non-null object
# end_station_description      11203 non-null object
# end_station_latitude         11404 non-null float64
# end_station_longitude        11404 non-null float64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 1.1+ MB

# %%
# Convert first 2 columns to datetime objects
trips['started_at'] = pd.to_datetime(trips['started_at'])
trips['ended_at'] = pd.to_datetime(trips['ended_at'])

# Display some properties of the datetime objects
trips['started_at'][0].dayofweek
# Out:
# 3

# %%
# Create a new column to indicate the day of the week
trips['day_of_week'] = trips['started_at'].dt.dayofweek
trips.tail()
# Out:
#                             started_at                         ended_at  \
# 11399 2021-07-31 23:46:33.308000+00:00 2021-08-01 00:01:28.832000+00:00
# 11400 2021-07-31 23:50:02.642000+00:00 2021-07-31 23:58:50.684000+00:00
# 11401 2021-07-31 23:54:54.719000+00:00 2021-08-01 00:06:35.941000+00:00
# 11402 2021-07-31 23:55:44.291000+00:00 2021-08-01 00:07:11.259000+00:00
# 11403 2021-07-31 23:58:16.144000+00:00 2021-08-01 00:15:35.242000+00:00
#
#        duration  start_station_id start_station_name  \
# 11399       895              1019        Grassmarket
# 11400       528              1028      Hunter Square
# 11401       701              1722  Cramond Foreshore
# 11402       686              1722  Cramond Foreshore
# 11403      1039              1748      Colinton Road
#
#                       start_station_description  start_station_latitude  \
# 11399                   West end of Grassmarket               55.947097
# 11400        In Hunter Square next to Tron Kirk               55.949798
# 11401                        Near Cramond Beach               55.980031
# 11402                        Near Cramond Beach               55.980031
# 11403  Near Napier University Merchiston Campus               55.933416
#
#        start_station_longitude  end_station_id   end_station_name  \
# 11399                -3.197246             258        Stockbridge
# 11400                -3.187795             358         Leith Walk
# 11401                -3.300642            1722  Cramond Foreshore
# 11402                -3.300642            1722  Cramond Foreshore
# 11403                -3.212397            1744   Morningside Road
#
#                       end_station_description  end_station_latitude  \
# 11399        Hamilton Place by Dean Bank Lane             55.958566
# 11400      Leith Walk opposite Dalmeny Street             55.965176
# 11401                      Near Cramond Beach             55.980031
# 11402                      Near Cramond Beach             55.980031
# 11403  Corner of Morningside Park, beside M&S             55.927985
#
#        end_station_longitude  day_of_week
# 11399              -3.208070            5
# 11400              -3.176180            5
# 11401              -3.300642            5
# 11402              -3.300642            5
# 11403              -3.209750            5

# %%
# Calculate average trip duration on weekends
trips.loc[trips['day_of_week'] >= 5, 'duration'].mean() / 60

trips.loc[trips['day_of_week'] < 5, 'duration'].mean() / 60
# Out:
# 30.86108918873048

# %%
import seaborn as sns
from numpy import median

grid = sns.catplot(data=trips,
                   x='day_of_week',
                   y='duration',
                   kind='bar',
                   ci=None,
                   estimator=median)

# %%
# %matplotlib notebook

grid = sns.catplot(data=trips,
                   kind='violin',
                   x='day_of_week',
                   y='duration',
                   ylim=[0, 10000])
# Out:
# <img src="data:image/png;base64,..." width="499.84">

# %%
# %matplotlib inline
grid = sns.displot(data=trips,
                   x='duration',
                   hue='day_of_week',
                   kind='kde',
                   log_scale=True,
                   common_norm=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9100/3511577182.py in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 grid = sns.displot(data=trips,
#       3                    x='duration',
#       4                    hue='day_of_week',
#       5                    kind='kde',
#
# AttributeError: module 'seaborn' has no attribute 'displot'
